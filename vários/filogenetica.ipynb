# %%
from Bio import Phylo

import matplotlib.pyplot as plt

SMALL_SIZE = 5
MEDIUM_SIZE = 5
BIGGER_SIZE = 9

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

alignment = open('TCF7L2_blastprot.xml.dnd')
tree = Phylo.read(alignment, 'newick')
tree.ladderize()
Phylo.draw_ascii(tree)

tree = tree.as_phyloxml()
tree.ladderize() # Flip branches so deeper clades are displayed at top
tree.root.color = "blue"
Phylo.draw(tree)
#Phylo.draw(tree, branch_labels=lambda c: c.branch_length)
# Out:
#          ___________ emb|CAB97213.1|
#   ______|
#  |      |                         _______ ref|XP_011898314.1|
#  |      |________________________|
#  |                               |___________________ emb|CAB97215.1|
#  |
#  | , ref|XP_045217476.1|
#  | |
#  | |      , ref|XP_011898315.1|
#  | |     ,|
#  | |     ||_____ ref|XP_037864729.1|
#  |_| ____|
#  | ||    |  , ref|XP_026302445.1|
#  | ||    |__|
#  | ||       , ref|XP_026302446.1|
#  | ||       |
#  | ||       |    , ref|XP_030796775.1|
#  |  |       |____|
#  |  |            | ref|XP_030796774.1|
#  |  |
# _|  |, ref|XP_045217474.1|
#  |  ||
#  |  ||  , ref|XP_015003694.2|
#  |   |  |
#  |   |__|      , ref|XP_024109206.1|
#  |      |    __|
#  |      |   |  | ref|XP_032137517.1|
#  |      |___|
#  |          |, ref|XP_045217475.1|
#  |          ||
#  |           |__ ref|XP_028682676.1|
#  |
#  , ref|XP_024109208.1|
#  |
#  |, ref|XP_016774826.1|
#  ||
#  ||, ref|XP_021532634.1|
#  |||
#  | |, ref|XP_032137516.1|
#  | ||
#  |  |   , ref|XP_035124988.1|
#  |  |___|
#  |      | ref|XP_035124986.1|
#  |
#  |, ref|NP_001354872.1|
#  ||
#  ||, gb|KAI2557293.1|
#   ||
#   ||              ________________ ref|XP_013371314.1|
#   ||             |
#    |             |    __________________________ ref|XP_045004723.1|
#    |             |   |
#    |_____________|   |                      __ ref|XP_049711863.1|
#                  |   |        _____________|
#                  |   |       |             |____ ref|XP_007939751.1|
#                  |   |       |
#                  |   |   ____|        _____ ref|XP_016001798.2|
#                  |___|  |    |       |
#                      |  |    |       |  ______ ref|XP_022355666.1|
#                      |  |    |_______|_|
#                      |  |            | |  , ref|XP_032985921.1|
#                      |  |            | |__|
#                      |  |            |    |________ ref|XP_019502149.1|
#                      |  |            |
#                      |  |            |  _________ ref|XP_045709913.1|
#                      |__|            |_|
#                         |              | ________ ref|XP_026349928.1|
#                         |              ||
#                         |               |         , ref|XP_012422226.1|
#                         |               |_________|
#                         |                         |____ ref|XP_032279274.1|
#                         |
#                         |              _ ref|XP_040848011.1|
#                         |    _________|
#                         |   |         |______ ref|XP_004579871.1|
#                         |___|
#                             |  _____________ ref|XP_020022599.1|
#                             | |
#                             |_|  _______________ ref|XP_042545092.1|
#                               | |
#                               | |                ___ ref|XP_006978487.1|
#                               |_|    ___________|
#                                 |   |           |_ ref|XP_028730926.1|
#                                 |   |
#                                 |___|    _______ ref|XP_051002761.1|
#                                     |  _|
#                                     | | |__________ ref|XP_021486674.1|
#                                     | |
#                                     |_|         __ ref|XP_021043247.1|
#                                       |     ___|
#                                       |    |   |_ ref|NP_001318075.1|
#                                       |____|
#                                            |    ______ ref|XP_031246596.1|
#                                            |___|
#                                                | , ref|XP_034371804.1|
#                                                |_|
#                                                  |____ ref|XP_028630162.1|
#                                                  |
#                                                  |____ ref|XP_032748208.1|
